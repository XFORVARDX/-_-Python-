# %% [markdown]
# Для заданного каталога определить число хранимых файлов (содержит не только файлы изображений (каталог2)).
# Организовать процесс чтения файлов из задаваемого каталога с именами только типа *.bmp.
# Преобразовать изображение в индексное  с палитрой по умолчанию из 128 цветов.
# Вычислить объем хранимой информации в байтах – v.
# Записать  в массив  объем хранимой в изображении информации в байтах по каждому файлу

# %%
from PIL import Image 
import os
import matplotlib.pyplot as plt

# %%
img_array=[]
for file in os.listdir("C:\\Users\\Федя\\Desktop\\комп граф\\1"):
    if file.endswith(".bmp") and (os.path.isfile(file)== True) :

        print(os.path.join(file))
        a=os.path.join(file)
        try:  
            img = Image.open(os.path.join(file)) 
            imageL = img.convert("P", dither=0)
            img_array.append([os.path.join(file),os.path.getsize(a)])
        except FileNotFoundError:  
            print("Файл не найден")
        
        
img_array
# Out:
# GTR16.bmp
# GTR256.bmp
# GTR_img.bmp
# out.bmp
# [['GTR16.bmp', 4147318],
#  ['GTR256.bmp', 8295478],
#  ['GTR_img.bmp', 900054],
#  ['out.bmp', 8295478]]

# %%
img#.show
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=3840x2160 at 0x2C691843AC0>

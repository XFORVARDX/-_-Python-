# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
ЗАДАНИЕ 1

# %%
try:  
    img = Image.open("Penguins.jpg")  
except FileNotFoundError:  
    print("Файл не найден")

# %%
img#.show
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x290E3741700>

# %%
try:  
    img16 = Image.open("Penguins16.bmp") 
    img256 = Image.open("Penguins256.bmp") 
except FileNotFoundError:  
    print("Файл не найден")

# %%
img16#.show
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=P size=1024x768 at 0x290E58E1310>

# %%
img256#.show
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=P size=1024x768 at 0x290E3642820>

# %%
B = img256.convert("P", dither=0)
plt.imshow(B)

# %%
A_np = np.array(img16)
A_np
# Out:
# array([[8, 8, 8, ..., 7, 7, 7],
#        [8, 8, 8, ..., 7, 7, 7],
#        [8, 8, 8, ..., 7, 7, 7],
#        ...,
#        [7, 7, 8, ..., 7, 7, 7],
#        [7, 7, 7, ..., 7, 7, 7],
#        [7, 7, 7, ..., 7, 7, 7]], dtype=uint8)

# %%
B_np = np.array(img256)
B_np
# Out:
# array([[236, 236, 236, ..., 235, 235, 235],
#        [244, 236, 236, ..., 235, 235, 235],
#        [244, 236, 236, ..., 235, 235, 235],
#        ...,
#        [ 99, 164, 182, ..., 164, 163, 155],
#        [163, 163,  90, ..., 164, 164, 163],
#        [ 90, 155,  91, ..., 163, 163, 155]], dtype=uint8)

# %%
ЗАДАНИЕ 2

# %%
A = img256
A.show()
#ОТКРЫВАЕТСЯ ОТДЕЛЬНОЕ ОКНО В ПРОВОДНИКЕ ГДЕ ПОЯВЛЯЕТСЯ ИЗОБРАЖЕНИЕ

# %%
A = img16
plt.imshow(A)

# %%
ЗАДАНИЕ 3

# %%
for_save = img256.convert(mode='L',dither=1)
for_save.save('out.bmp')

# %%
ЗАДАНИЕ 4

# %%
A = img.convert("P", dither=1)
plt.imshow(A)

# %%
B = img.convert("P", dither=0)
plt.imshow(B)

# %%
ЗАДАНИЕ 5

# %%
img256.getpixel((25,25))
# Out:
# 244

# %%
img256.putpixel((15,25),(100,50,100))
img256.getpixel((15,25))
# Out:
# 253

# %%
image_np = np.array(img)
plt.imshow(image_np)
plt.show()

# %%
image_np[25,25,:] = [0,0,100]
image_np[25,25,:]
# Out:
# array([  0,   0, 100], dtype=uint8)

# %%
ЗАДАНИЕ 6

# %%
image_crop = img.crop([200,300,800,500,])
image_crop
# Out:
# <PIL.Image.Image image mode=RGB size=600x200 at 0x290E5AC9D90>

# %%
image_crop.save('out_img.bmp')

# %%
plt.imshow(img)
plt.show()

# %%
ЗАДАНИЕ 7

# %%
image_nd2 = np.concatenate((img16, img256), axis=0)

plt.imshow(image_nd2)
plt.show()

# %%
image_nd2 = np.concatenate((img16, img256), axis=1)

plt.imshow(image_nd2)
plt.show()

# %% [markdown]
# # Задание 1

# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

try:  
    X = Image.open('валера киборг.jpg')  
except FileNotFoundError:  
    print("Файл не найден")

# %%
plt.imshow(X)
plt.show()
X.size
# Out:
# (800, 450)

# %%
I1_1 = X.resize((100, 100), Image.NEAREST)
plt.imshow(I1_1)

# %%
I2_1 = X.resize((100, 100), Image.BICUBIC)
plt.imshow(I2_1)

# %%
I1_2 = X.resize((1000, 1000), Image.NEAREST)
plt.imshow(I1_2)

# %%
I2_2 = X.resize((1000, 1000), Image.BICUBIC)
plt.imshow(I2_2)

# %%
plt.subplot(1,2,1)
plt.imshow(np.array(X)[1000:20,0:200])
plt.subplot(1,2,2)
plt.imshow(np.array(I1_1)[0:190,0:25])
plt.show()

# %%
plt.subplot(1,2,1)
plt.imshow(np.array(X)[0:200,0:200])
plt.subplot(1,2,2)
plt.imshow(np.array(I2_1)[0:190,0:25])
plt.show()

# %%
plt.subplot(1,2,1)
plt.imshow(np.array(X)[0:200,0:200])
plt.subplot(1,2,2)
plt.imshow(np.array(I1_2)[0:1800,0:250])
plt.show()

# %%
plt.subplot(1,2,1)
plt.imshow(np.array(X)[0:200,0:200])
plt.subplot(1,2,2)
plt.imshow(np.array(I2_2)[0:1800,0:250])
plt.show()

# %% [markdown]
# # Задание 2

# %%
X2 = X.convert("L",dither = 0)

# %%
from PIL import ImageEnhance
Xb = ImageEnhance.Brightness(X2)

# %%
B1 = Xb.enhance(10)
B1
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x260DC96B3D0>

# %%
B2 = Xb.enhance(128)
B2
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x260DC974610>

# %%
B3 = Xb.enhance(255)
B3
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x260DC9745E0>

# %% [markdown]
# # Задание 3

# %%
Hist = plt.plot(X2.histogram())
Hist1 = plt.plot(B1.histogram())
Hist2 = plt.plot(B2.histogram())
Hist3 = plt.plot(B3.histogram())
plt.show()

# %% [markdown]
# # Задание 4

# %%
Contr = ImageEnhance.Contrast(X2)
C1 = Contr.enhance(1.5)
C1
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x260DC9CD1F0>

# %% [markdown]
# # Задание 5
